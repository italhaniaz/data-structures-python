# %% [markdown]
# # <b> Heap Data Structure and Heap Sort </b>

# %% [markdown]
# ## <b> Heap data structure - MaxHeap and MinHeap </b>

# %%
n = 8
for i in reversed(range(n)):
    print(i)
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
def heapify(lst, n, root):
    """ Heapify the root element of lst which has n elements in total """
    largest = root
    l = 2*root + 1
    r = 2*root + 2

    if l < n and lst[l] > lst[largest]:
        largest = l

    if r < n and lst[r] > lst[largest]:
        largest = r

    if largest != root:
        lst[root], lst[largest] = lst[largest], lst[root]

        heapify(lst, n, largest)

# %%
def build_heap(lst):
    """ Construct heap from any list by repeatedly applying heapify from bottom non-leaf """

    n = len(lst)

    for i in reversed(range(n//2)):     #rest must be leaves, so, no need to heapify
        #print("Heapify: ", lst[i])
        heapify(lst, n, i)

# %%
heap = [100, 5, 3, 2, 8, 15, 6, 102]
print(heap)
build_heap(heap)
print(heap)
# Out:
# [100, 5, 3, 2, 8, 15, 6, 102]
# [102, 100, 15, 5, 8, 3, 6, 2]

# %%
def heap_sort(lst):
    """ Perfome a Heap sort by building a max heap from the list and then repeatedly retire """
    n = len(lst)

    #Build max heap
    build_heap(heap)

    for i in reversed(range(n)):
        #swap
        lst[i], lst[0] = lst[0], lst[i]

        #heapify root element again but only untill the ith element 
        heapify (lst, i, 0)

# %%
heap = [100, 5, 3, 2, 8, 15, 6, 102]
print(heap)
heap_sort(heap)
print(heap)
# Out:
# [100, 5, 3, 2, 8, 15, 6, 102]
# [2, 3, 5, 6, 8, 15, 100, 102]
