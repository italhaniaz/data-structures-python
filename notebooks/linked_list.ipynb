# %% [markdown]
# # <b> Linked List </b>

# %%
class Node:
    def __init__(self, data=None):
        self.val = data
        self.next = None

class LindedList:
    def __init__(self):
        self.head = None

# %% [markdown]
# ## Push Operation

# %%
def push(self, value):
    new_node = Node(value)

    if self.head is None:
        self.head = new_node
        return 

    last = self.head
    
    while last.next is not None:
        last = last.next
        
    last.next = new_node

LindedList.push = push

# %%
# For to see it visually we need to create __str__ dunder function

# %%
def __str__(self):
    ret_str = '['
    temp = self.head

    while temp is not None:
        ret_str += str(temp.val) + ', '
        temp = temp.next

    ret_str = ret_str.rstrip(', ')
    ret_str += ']'

    return ret_str

LindedList.__str__ = __str__

# %%
l = LindedList()

# %%
l.push(1)
l.push(2)
l.push(3)
print(l)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Pop operation

# %%
def pop(self):
    if self.head is None:
        raise Exception("Cannot pop. No value")

    #Case where there is only one node 
    if self.head.next is None:
        ret_val = self.head.val
        self.head = None
        return ret_val

    #Case where there is 2 or more nodes 
    temp = self.head
    while temp.next is not None:
        prev = temp
        temp = temp.next 

    ret_val = temp.val
    prev.next = None

    return ret_val

LindedList.pop = pop

# %%
l

# %%
print(l)
# Out:
# [1, 2, 3]

# %%
l.pop()
print(l)
# Out:
# [1, 2]

# %% [markdown]
# ## Insertion Operatoin

# %%
def insert(self, index, val):
    new_node = Node(val)

    if index == 0:
        new_node.next = self.head
        self.head = new_node
        return 

    # for other indices
    temp = self.head
    counter = 0
    while temp is not None and counter < index:
        if counter == index:
            break

        prev = temp 
        temp = temp.next
        counter += 1

    if temp is None:
        return 

    prev.next = new_node
    new_node.next = temp

LindedList.insert = insert

# %%
print(l)
# Out:
# [1, 2]

# %%
l.push(3)
l.push(4)
l.push(5)

# %%
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l.insert(1, -2)

# %%
print(l)
# Out:
# [1, -2, 2, 3, 4, 5]

# %%
l.insert(0, 0)
print(l)
# Out:
# [0, 1, -2, 2, 3, 4, 5]

# %%
l.pop()
# Out:
# 5

# %%
print(l)
# Out:
# [0, 1, -2, 2, 3, 4]

# %% [markdown]
# ## Remove operation

# %%
def remove(self, val):
    temp = self.head

    if temp is not None:
        if temp.val == val:
            self.head = temp.next
            return 

    while temp is not None:
        if temp.val == val:
            break

        prev = temp
        temp = temp.next

    if temp is None:
        return 

    prev.next = temp.next

LindedList.remove = remove

# %%
l.remove(-2)

# %%
print(l)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Assingment -> make len() and get(index) Operations

# %% [markdown]
# ## Length Operation

# %%
def lenght(self):
    temp = self.head

    counter = 0
    while temp is not None:
        temp = temp.next
        counter += 1

    return counter

LindedList.len = lenght

# %%
l.len()
# Out:
# 5

# %% [markdown]
# ## Get Operation

# %%
def get(self, index):
    temp = self.head 
    counter = 0

    while temp is not None and counter < index:
        if counter == index:
            break

        temp = temp.next
        counter += 1

    if temp is None:
        return 

    val = temp.val
    return val

LindedList.get = get

# %%
l.get(4)
# Out:
# 4

# %%
l.get(0)
# Out:
# 0
