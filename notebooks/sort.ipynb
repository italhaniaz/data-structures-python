# %% [markdown]
# # <b> Bubble Sort </b>

# %%
def bubble_sort(lst):
    n = len(lst)
    # print(n)

    # outer loop. Goes over the whole thing 'n' times
    # (because each time, one 'higest' will have moved to end)
    for i in range(n):

        #try to bubble the higest one up
        for j in range(0, (n-1)-i):

            #compare pairs, move higher one up (the higest will always reach the end)
            if l[j] > l[j+1]:
                l[j], l[j+1] = l[j+1], l[j]

# %%
l = [1, 2, 4, 1, 2, 5, 5, 6, 1, 110, 15]
bubble_sort(l)
print(l)
# Out:
# [1, 1, 1, 2, 2, 4, 5, 5, 6, 15, 110]

# %% [markdown]
# # <b> Insertion Sort </b>

# %%
def insertion_sort(l):

    # Go through all elements (except first)
    # Call it 'key'
    # Each time, the key would be 'inserted' in its place
    # At each iteration, stuff less than i would be sorted already

    for i in range(1, len(l)):

        key = l[i]  # Hold the key

        # start comparing keys to things on its left!
        # stop when less or equal value found (or we reach left end)

        j = i-1

        while j >= 0 and key < l[j]:
            l[j+1] = l[j]   # move this to right. So left on j
            j -= 1

        l[j+1] = key # Place key in free slot ... (j+1 because we decremented j above)

# %%
l = [1, 2, 4, 1, 2, 5, 5, 6, 1, 110, 15]
insertion_sort(l)
# %tiprint(l)
# Out:
# [1, 1, 1, 2, 2, 4, 5, 5, 6, 15, 110]
